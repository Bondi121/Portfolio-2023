# %%
import chart_studio.plotly as py
import plotly.graph_objs as go 
import pandas as pd
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df_east = pd.read_csv('eastern_conference.csv')
df_west = pd.read_csv('western_conference.csv')

# %%
import numpy as np
w_values = df_east["W"].values
mean_w = np.mean(w_values)
max_w = np.max(w_values)
min_w = np.min(w_values)
print("Mean W:", mean_w)
print("Max W:", max_w)
print("Min W:", min_w)
# Out:
# Mean W: 41.06666666666667
# Max W: 53
# Min W: 22

# %%
# !pip install -U kaleido
# Out:
# ...
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/65.9 MB ? eta -:--:--
#                                               0.3/65.9 MB 6.5 MB/s eta 0:00:11
#                                               0.9/65.9 MB 9.6 MB/s eta 0:00:07
#                                               1.1/65.9 MB 9.1 MB/s eta 0:00:08
#                                               1.1/65.9 MB 9.1 MB/s eta 0:00:08
#                                               1.5/65.9 MB 6.6 MB/s eta 0:00:10
#                                               1.6/65.9 MB 5.4 MB/s eta 0:00:12
#      -                                        2.7/65.9 MB 7.7 MB/s eta 0:00:09
#      -                                        2.8/65.9 MB 7.9 MB/s eta 0:00:09
#      -                                        2.9/65.9 MB 7.0 MB/s eta 0:00:10
# ...

# %%
import plotly.graph_objects as go

# Compute mean, max, and min W
w_values = df_east["W"].values
mean_w = np.mean(w_values)
max_w = np.max(w_values)
min_w = np.min(w_values)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=[mean_w], y=["Mean W"], orientation="h", name="Mean W"))
fig.add_trace(go.Bar(x=[max_w], y=["Max W"], orientation="h", name="Max W"))
fig.add_trace(go.Bar(x=[min_w], y=["Min W"], orientation="h", name="Min W"))
fig.update_layout(title="Win Statistics Eastern Conference", xaxis_title="W", yaxis_title="")
fig.show()
fig.write_image("eastern_w_stats123.png")
# Out:
# <div>                            <div id="07fbf2e6-21e6-4f50-b9eb-ef8671bb970a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07fbf2e6-21e6-4f50-b9eb-ef8671bb970a")) {                    Plotly.newPlot(                        "07fbf2e6-21e6-4f50-b9eb-ef8671bb970a",                        [{"name":"Mean W","orientation":"h","x":[41.06666666666667],"y":["Mean W"],"type":"bar"},{"name":"Max W","orientation":"h","x":[53],"y":["Max W"],"type":"bar"},{"name":"Min W","orientation":"h","x":[22],"y":["Min W"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333
# ...

# %%
import plotly.graph_objects as go

# Compute mean, max, and min W
w_values = df_west["W"].values
mean_w = np.mean(w_values)
max_w = np.max(w_values)
min_w = np.min(w_values)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=[mean_w], y=["Mean W"], orientation="h", name="Mean W"))
fig.add_trace(go.Bar(x=[max_w], y=["Max W"], orientation="h", name="Max W"))
fig.add_trace(go.Bar(x=[min_w], y=["Min W"], orientation="h", name="Min W"))
fig.update_layout(title="Win Statistics Western Conference", xaxis_title="W", yaxis_title="")
fig.show()
fig.write_image("western_w_stats123.png")
# Out:
# <div>                            <div id="3f2f4ce8-95db-42c9-9d7b-5cfcf53b7b2b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f2f4ce8-95db-42c9-9d7b-5cfcf53b7b2b")) {                    Plotly.newPlot(                        "3f2f4ce8-95db-42c9-9d7b-5cfcf53b7b2b",                        [{"name":"Mean W","orientation":"h","x":[40.93333333333333],"y":["Mean W"],"type":"bar"},{"name":"Max W","orientation":"h","x":[64],"y":["Max W"],"type":"bar"},{"name":"Min W","orientation":"h","x":[20],"y":["Min W"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")

# Create a histogram of W values
sns.histplot(data=df_east, x="W", kde=True)

# Add mean, max, and min lines to the plot
plt.axvline(mean_w, color='r', linestyle='--', label="Mean W")
plt.axvline(max_w, color='g', linestyle='--', label="Max W")
plt.axvline(min_w, color='b', linestyle='--', label="Min W")

# Add legend to the plot
plt.legend()

# Add title and axis labels
plt.title("Distribution of W Values in Eastern Conference")
plt.xlabel("W")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %%
playoffs = df_east["Eastern Conference"].str.endswith("*").values
print(playoffs)
# Out:
# [ True  True  True  True  True  True  True False  True False False False
#  False False False]

# %%
playoff_srs = df_east.loc[playoffs, "SRS"].values
non_playoff_srs = df_east.loc[~playoffs, "SRS"].values
avg_playoff_srs = np.mean(playoff_srs)
avg_non_playoff_srs = np.mean(non_playoff_srs)
print("Avg Playoff SRS:", avg_playoff_srs)
print("Avg Non-Playoff SRS:", avg_non_playoff_srs)
# Out:
# Avg Playoff SRS: 2.67625
# Avg Non-Playoff SRS: -2.7085714285714286

# %%
import plotly.graph_objects as go
import numpy as np

# Compute mean, max, and min W for the Eastern Conference
df_east = df[df["Conference"] == "East"]
w_values = df_east["W"].values
mean_w = np.mean(w_values)
max_w = np.max(w_values)
min_w = np.min(w_values)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=[mean_w], y=["Mean W"], orientation="h", name="Mean W"))
fig.add_trace(go.Bar(x=[max_w], y=["Max W"], orientation="h", name="Max W"))
fig.add_trace(go.Bar(x=[min_w], y=["Min W"], orientation="h", name="Min W"))
fig.update_layout(title="W Statistics for Eastern Conference", xaxis_title="W", yaxis_title="")
fig.show()

# Save the plot as a png image
fig.write_image("eastern_w_stats.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       2 import numpy as np
#       4 # Compute mean, max, and min W for the Eastern Conference
# ----> 5 df_east = df[df["Conference"] == "East"]
#       6 w_values = df_east["W"].values
#       7 mean_w = np.mean(w_values)
#
# NameError: name 'df' is not defined

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Compute mean, max, and min W for both conferences
east_w_values = df_east["W"].values
east_mean_w = np.mean(east_w_values)
east_max_w = np.max(east_w_values)
east_min_w = np.min(east_w_values)

west_w_values = df_west["W"].values
west_mean_w = np.mean(west_w_values)
west_max_w = np.max(west_w_values)
west_min_w = np.min(west_w_values)

# Create subplots with 1 row and 2 columns
fig = make_subplots(rows=1, cols=2, subplot_titles=("Eastern Conference", "Western Conference"))

# Add bar charts to subplots
fig.add_trace(go.Bar(x=[east_mean_w], y=["Mean W"], orientation="h", name="Mean W"), row=1, col=1)
fig.add_trace(go.Bar(x=[east_max_w], y=["Max W"], orientation="h", name="Max W"), row=1, col=1)
fig.add_trace(go.Bar(x=[east_min_w], y=["Min W"], orientation="h", name="Min W"), row=1, col=1)
fig.update_xaxes(title_text="W", row=1, col=1)

fig.add_trace(go.Bar(x=[west_mean_w], y=["Mean W"], orientation="h", name="Mean W"), row=1, col=2)
fig.add_trace(go.Bar(x=[west_max_w], y=["Max W"], orientation="h", name="Max W"), row=1, col=2)
fig.add_trace(go.Bar(x=[west_min_w], y=["Min W"], orientation="h", name="Min W"), row=1, col=2)
fig.update_xaxes(title_text="W", row=1, col=2)

# Update layout
fig.update_layout(title="Win Statistics by Conference", height=400)

# Show figure
fig.show()
# Out:
# <div>                            <div id="28f9ea78-aaa0-4a7e-91a6-27c79dd11bfe" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("28f9ea78-aaa0-4a7e-91a6-27c79dd11bfe")) {                    Plotly.newPlot(                        "28f9ea78-aaa0-4a7e-91a6-27c79dd11bfe",                        [{"name":"Mean W","orientation":"h","x":[41.06666666666667],"y":["Mean W"],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Max W","orientation":"h","x":[53],"y":["Max W"],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Min W","orientation":"h","x":[22],"y":["Min W"],"type":"bar","xaxis":"x","yaxis":"y"},{"name":"Mean W","orientation":"h","x":[40.93333333333333],"y":["Mean W"],"type":"bar","xaxis":"x2","yaxis":"y2"},{"name":"Max W","orientation":"h","x":[64],"y":["Ma
# ...

# %%
import plotly.graph_objects as go

# Compute mean, max, and min W for Eastern Conference
w_values_east = df_east["W"].values
mean_w_east = np.mean(w_values_east)
max_w_east = np.max(w_values_east)
min_w_east = np.min(w_values_east)

# Compute mean, max, and min W for Western Conference
w_values_west = df_west["W"].values
mean_w_west = np.mean(w_values_west)
max_w_west = np.max(w_values_west)
min_w_west = np.min(w_values_west)

# Create subplots
fig = make_subplots(rows=1, cols=2, shared_yaxes=True)

# Add bar chart for Eastern Conference
fig.add_trace(go.Bar(x=[mean_w_east], y=["Mean W"], orientation="h", name="Mean W", marker_color="#1f77b4"), row=1, col=1)
fig.add_trace(go.Bar(x=[max_w_east], y=["Max W"], orientation="h", name="Max W", marker_color="#ff7f0e"), row=1, col=1)
fig.add_trace(go.Bar(x=[min_w_east], y=["Min W"], orientation="h", name="Min W", marker_color="#2ca02c"), row=1, col=1)
fig.update_xaxes(title_text="W", row=1, col=1)
fig.update_yaxes(title_text="Eastern Conference", row=1, col=1)

# Add bar chart for Western Conference
fig.add_trace(go.Bar(x=[mean_w_west], y=["Mean W"], orientation="h", name="Mean W", marker_color="#1f77b4"), row=1, col=2)
fig.add_trace(go.Bar(x=[max_w_west], y=["Max W"], orientation="h", name="Max W", marker_color="#ff7f0e"), row=1, col=2)
fig.add_trace(go.Bar(x=[min_w_west], y=["Min W"], orientation="h", name="Min W", marker_color="#2ca02c"), row=1, col=2)
fig.update_xaxes(title_text="W", row=1, col=2)
fig.update_yaxes(title_text="Western Conference", row=1, col=2)

# Update layout
fig.update_layout(title="Win Statistics", height=400)

# Show figure
fig.show()

# Save figure
fig.write_image("win_statistics.png")
# Out:
# <div>                            <div id="d07116b8-7257-4d9f-9169-d2822af5a8fb" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d07116b8-7257-4d9f-9169-d2822af5a8fb")) {                    Plotly.newPlot(                        "d07116b8-7257-4d9f-9169-d2822af5a8fb",                        [{"marker":{"color":"#1f77b4"},"name":"Mean W","orientation":"h","x":[41.06666666666667],"y":["Mean W"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#ff7f0e"},"name":"Max W","orientation":"h","x":[53],"y":["Max W"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#2ca02c"},"name":"Min W","orientation":"h","x":[22],"y":["Min W"],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#1f77b4"},"name":"Mean W","orientation":"h","x":[40.933333
# ...

# %%
import plotly.graph_objects as go

# Compute mean, max, and min W for Eastern and Western conferences
w_values_east = df_east["W"].values
mean_w_east = np.mean(w_values_east)
max_w_east = np.max(w_values_east)
min_w_east = np.min(w_values_east)

w_values_west = df_west["W"].values
mean_w_west = np.mean(w_values_west)
max_w_west = np.max(w_values_west)
min_w_west = np.min(w_values_west)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[mean_w_east, mean_w_west], name='Mean W'))
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[max_w_east, max_w_west], name='Max W'))
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[min_w_east, min_w_west], name='Min W'))
fig.update_layout(title="Win Statistics", xaxis_title="Conference", yaxis_title="W", barmode='group')
fig.show()
fig.write_html("combined_w_stats.html")
# Out:
# <div>                            <div id="6227a332-44ba-45d0-bf7e-00dc8674d9c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6227a332-44ba-45d0-bf7e-00dc8674d9c3")) {                    Plotly.newPlot(                        "6227a332-44ba-45d0-bf7e-00dc8674d9c3",                        [{"name":"Mean W","x":["Eastern Conference","Western Conference"],"y":[41.06666666666667,40.93333333333333],"type":"bar"},{"name":"Max W","x":["Eastern Conference","Western Conference"],"y":[53,64],"type":"bar"},{"name":"Min W","x":["Eastern Conference","Western Conference"],"y":[22,20],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"
# ...

# %%
import plotly.graph_objects as go
import plotly.offline as pyo

# Compute mean, max, and min W for Eastern Conference
w_values_east = df_east["W"].values
mean_w_east = np.mean(w_values_east)
max_w_east = np.max(w_values_east)
min_w_east = np.min(w_values_east)

# Compute mean, max, and min W for Western Conference
w_values_west = df_west["W"].values
mean_w_west = np.mean(w_values_west)
max_w_west = np.max(w_values_west)
min_w_west = np.min(w_values_west)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=["Eastern Conference", "Western Conference"], y=[mean_w_east, mean_w_west], name="Mean W"))
fig.add_trace(go.Bar(x=["Eastern Conference", "Western Conference"], y=[max_w_east, max_w_west], name="Max W"))
fig.add_trace(go.Bar(x=["Eastern Conference", "Western Conference"], y=[min_w_east, min_w_west], name="Min W"))
fig.update_layout(title="Win Statistics", xaxis_title="", yaxis_title="W")

# Save the plot as an HTML file
fig_html = pyo.plot(fig, include_plotlyjs=False, output_type='div')
with open('win_statistics.html', 'w') as f:
    f.write(fig_html)

# %%
import plotly.graph_objects as go

# Compute mean, max, and min W for Eastern and Western conferences
w_values_east = df_east["W"].values
mean_w_east = np.mean(w_values_east)
max_w_east = np.max(w_values_east)
min_w_east = np.min(w_values_east)

w_values_west = df_west["W"].values
mean_w_west = np.mean(w_values_west)
max_w_west = np.max(w_values_west)
min_w_west = np.min(w_values_west)

# Create bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[mean_w_east, mean_w_west], name='Mean W'))
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[max_w_east, max_w_west], name='Max W'))
fig.add_trace(go.Bar(x=['Eastern Conference', 'Western Conference'], y=[min_w_east, min_w_west], name='Min W'))
fig.update_layout(title="Win Statistics", xaxis_title="Conference", yaxis_title="W", barmode='group')
fig.show()
fig.write_html("combined_w_stats111.html")
# Out:
# <div>                            <div id="6c878d00-87c4-449b-9519-f9e141dfb18a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c878d00-87c4-449b-9519-f9e141dfb18a")) {                    Plotly.newPlot(                        "6c878d00-87c4-449b-9519-f9e141dfb18a",                        [{"name":"Mean W","x":["Eastern Conference","Western Conference"],"y":[41.06666666666667,40.93333333333333],"type":"bar"},{"name":"Max W","x":["Eastern Conference","Western Conference"],"y":[53,64],"type":"bar"},{"name":"Min W","x":["Eastern Conference","Western Conference"],"y":[22,20],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"
# ...
